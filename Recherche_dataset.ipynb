# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import ARDRegression

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

from zipfile import ZipFile

import datetime
import json
import re
import shutil

from tqdm import tqdm

import seaborn as sns

import ipywidgets
import os

import tensorflow as tf
import tensorflow.keras as keras
# Out:
# 2024-01-20 10:52:46.451429: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ### Poids

# %%
import_pathname = '/home/benjamin/Folders_Python/Weight_imports/'

# %%
# Récupère données POIDS

# récupère fichier zip le plus récent de HealthMate Withings
withings_filename = import_pathname + 'poids'  
with ZipFile(withings_filename, 'r') as weight_zip:
    weight_csv = weight_zip.extract('weight.csv', path=import_pathname)

# extrait la dataframe poids ----------------
colnames = ['Date', 'Poids (kg)', 'Gras (kg)', 'Masse osseuse (kg)', 'Masse musculaire (kg)', 'Hydratation (kg)']
df_weight = pd.read_csv(weight_csv, usecols=colnames)
os.remove(weight_csv)
df_weight.rename(columns = {'Poids (kg)' : 'Masse_Totale' , 
                            'Gras (kg)' : 'Masse_Grasse',
                            'Masse osseuse (kg)' : 'Masse_Osseuse',
                            'Masse musculaire (kg)' : 'Masse_Musculaire',
                            'Hydratation (kg)' : 'Masse_Hydrique'
                            }, 
                 inplace=True)

# transforme le champ str de Date en datetime objectdf_weight['std_MT'] = df_std['Masse_Totale']
date_format = '%Y-%m-%d %H:%M:%S'
df_weight['Date'] = df_weight['Date'].apply(lambda x : datetime.datetime.strptime(x, date_format).date())

# time cutoff
# on prend les data depuis le 1er Août 2020
# start_date = datetime.date(2020, 9, 1)
# df_weight = df_weight[df_weight['Date'] >= start_date]

# calcule MG% et BMR
subset = ['Masse_Totale', 'Masse_Grasse']
df_weight.dropna(subset = subset, inplace=True)
df_weight['MG%'] = df_weight['Masse_Grasse'] / df_weight['Masse_Totale']
df_weight['BMR'] = 370 + 21.6 * (df_weight['Masse_Totale'] - df_weight['Masse_Grasse'])  # Katch Mac Ardle
df_weight.sort_index(inplace=True)

# calcule moyennes et std dev par jour
df_std = df_weight.groupby('Date').std()
df_weight = df_weight.groupby('Date').mean()

for name in df_weight.columns:
    new_name = 'std_' + name
    df_weight[new_name] = df_std[name]
    
# nettoyage final
# df_weight.dropna(inplace=True)

# %%
df_weight
# Out:
#             Masse_Totale  Masse_Grasse  Masse_Osseuse  Masse_Musculaire  \
# Date
# 2001-01-01     72.000000     12.060000       3.000000         56.930000
# 2010-10-29     94.750000     22.325000            NaN               NaN
# 2010-10-30     93.216667     20.976667            NaN               NaN
# 2010-10-31     92.675000     23.385000            NaN               NaN
# 2010-11-01     92.950000     22.210000            NaN               NaN
# ...                  ...           ...            ...               ...
# 2024-01-16     72.593333     12.503333       3.002500         57.072500
# 2024-01-17     72.378462     12.340769       3.000000         57.022308
# 2024-01-18     73.055000     12.607500       3.020000         57.414167
# 2024-01-19     72.494167     12.419167       3.002500         57.056667
# 2024-01-20     72.846667     12.586667       3.010833         57.232500
#
#             Masse_Hydrique       MG%          BMR  std_Masse_Totale  \
# Date
# 2001-01-01       40.060000  0.167500  1664.704000               NaN
# 2010-10-29             NaN  0.235566  1934.380000          0.707107
# 2010-10-30             NaN  0.225046  1930.384000          0.057735
# 2010-10-31             NaN  0.252336  1866.664000          0.035355
# 2010-11-01             NaN  0.238946  1897.984000               NaN
# ...                    ...       ...          ...               ...
# 2024-01-16       40.121667  0.172237  1667.944000          0.139306
# 2024-01-17       40.098462  0.170503  1666.814154          0.026409
# 2024-01-18       40.441667  0.172574  1675.666000          0.135210
# 2024-01-19       40.122500  0.171311  1667.620000          0.158714
# 2024-01-20       40.268333  0.172782  1671.616000          0.094131
#
#             std_Masse_Grasse  std_Masse_Osseuse  std_Masse_Musculaire  \
# Date
# 2001-01-01               NaN                NaN                   NaN
# 2010-10-29          1.548564                NaN                   NaN
# 2010-10-30          6.509780                NaN                   NaN
# 2010-10-31          1.279863                NaN                   NaN
# 2010-11-01               NaN                NaN                   NaN
# ...                      ...                ...                   ...
# 2024-01-16          0.080941           0.006216              0.085187
# 2024-01-17          0.054842           0.000000              0.056296
# 2024-01-18          0.091266           0.006030              0.079938
# 2024-01-19          0.107319           0.004523              0.076555
# 2024-01-20          0.066788           0.002887              0.056589
#
#             std_Masse_Hydrique   std_MG%     std_BMR
# Date
# 2001-01-01                 NaN       NaN         NaN
# 2010-10-29                 NaN  0.014586   18.175473
# 2010-10-30                 NaN  0.069891  141.231464
# 2010-10-31                 NaN  0.013906   28.408722
# 2010-11-01                 NaN       NaN         NaN
# ...                        ...       ...         ...
# 2024-01-16            0.081222  0.000874    1.927567
# 2024-01-17            0.061758  0.000757    1.287433
# 2024-01-18            0.075538  0.001012    1.802780
# 2024-01-19            0.068772  0.001160    1.729227
# 2024-01-20            0.056057  0.000757    1.289438
#
# [1459 rows x 14 columns]

# %% [markdown]
# ### Calories

# %%
# Récupère données FOOD

mfp_filename = import_pathname + "food" # données de My Fitness Pal

# Extrait les archives
    
with ZipFile(mfp_filename, 'r') as food_zip:
    output_dir = food_zip.namelist()
    target = 'Nutrition-Summary'
    for l in output_dir:
        if l[:len(target)] == target:
            food_csv = food_zip.extract(l, path=import_pathname)
            break
        
# extrait la dataframe food -------------------------------

colnames = ['Date', 'Meal', 'Calories', 'Fat (g)', 'Carbohydrates (g)', 'Protein (g)']

df_food_raw = pd.read_csv(food_csv, usecols=colnames)
os.remove(food_csv)

df_food_raw.rename(columns = {'Fat (g)' : 'Lipides' , 'Carbohydrates (g)' : 'Glucides', 'Protein (g)' : 'Proteines'}, inplace=True)

# transforme le champ str de Date en datetime object

date_format = '%Y-%m-%d'

df_food_raw['Date'] = df_food_raw['Date'].apply(lambda x : datetime.datetime.strptime(x, date_format).date())
# df_food = df_food.groupby('Date').sum(numeric_only=True)

# start_date = datetime.date(2020, 8, 1)  # on prend les data depuis le 1er Août 2020

# df_food = df_food[df_food.index >= start_date]
# df_food.dropna(inplace=True)
# df_food.sort_index(inplace=True)

# %%
df_food_raw
# Out:
#             Date       Meal  Calories  Lipides  Glucides  Proteines
# 0     2020-08-03  Breakfast     621.4     27.9      69.7       22.4
# 1     2020-08-03     Dinner     581.6     20.4      84.5       17.1
# 2     2020-08-03      Lunch     656.0     41.4      26.6       33.5
# 3     2020-08-03     Snacks      58.0      0.0      14.0        0.0
# 4     2020-08-04  Breakfast    1111.6     49.0     137.8       34.3
# ...          ...        ...       ...      ...       ...        ...
# 3675  2024-01-17      Lunch     904.6     14.3      54.5      142.0
# 3676  2024-01-18  Breakfast     958.8     16.1      63.0      145.9
# 3677  2024-01-18     Dinner     702.7     25.3      61.4       48.6
# 3678  2024-01-19     Dinner     900.3     20.3     119.5       68.1
# 3679  2024-01-19      Lunch     770.7     17.2      34.0      119.7
#
# [3680 rows x 6 columns]

# %%
df_food = df_food_raw.groupby('Date').sum(numeric_only=True)

# %%
meal_types=['Breakfast', 'Dinner', 'Lunch', 'Snacks']
data_names=['Calories', 'Lipides', 'Glucides', 'Proteines']
col_names=['Date', 'Calories', 'Lipides', 'Glucides', 'Proteines']

for meal_type in meal_types:
    df_to_add = df_food_raw[df_food_raw['Meal']==meal_type][col_names].set_index('Date')
    mapping_data_names = { data_name : meal_type + '_' + data_name for data_name in data_names }
    df_to_add.rename(columns=mapping_data_names, inplace=True)
    df_food = pd.concat([df_food, df_to_add], axis=1)

# %%
df_food
# Out:
#             Calories  Lipides  Glucides  Proteines  Breakfast_Calories  \
# Date
# 2020-08-03    1917.0     89.7     194.8       73.0               621.4
# 2020-08-04    1992.7     67.7     267.5       78.4              1111.6
# 2020-08-05    1948.9     84.1     213.1       86.9              1174.2
# 2020-08-06    1937.2     66.4     134.3       60.0               747.0
# 2020-08-07    1674.0     67.5     168.9       95.2               791.9
# ...              ...      ...       ...        ...                 ...
# 2024-01-15    1684.4     21.5     186.3      189.9                 NaN
# 2024-01-16    1655.6     56.8     153.3      141.7                 NaN
# 2024-01-17    1637.2     29.5     174.6      183.0                 NaN
# 2024-01-18    1661.5     41.4     124.4      194.5               958.8
# 2024-01-19    1671.0     37.5     153.5      187.8                 NaN
#
#             Breakfast_Lipides  Breakfast_Glucides  Breakfast_Proteines  \
# Date
# 2020-08-03               27.9                69.7                 22.4
# 2020-08-04               49.0               137.8                 34.3
# 2020-08-05               51.6               147.1                 35.7
# 2020-08-06               35.3                81.4                 25.8
# 2020-08-07               35.5                91.6                 27.3
# ...                       ...                 ...                  ...
# 2024-01-15                NaN                 NaN                  NaN
# 2024-01-16                NaN                 NaN                  NaN
# 2024-01-17                NaN                 NaN                  NaN
# 2024-01-18               16.1                63.0                145.9
# 2024-01-19                NaN                 NaN                  NaN
#
#             Dinner_Calories  Dinner_Lipides  Dinner_Glucides  \
# Date
# 2020-08-03            581.6            20.4             84.5
# 2020-08-04            447.4             2.1             69.1
# 2020-08-05            136.7             6.7              3.2
# 2020-08-06            801.3            15.5             22.6
# 2020-08-07            397.5             7.2             75.4
# ...                     ...             ...              ...
# 2024-01-15            801.6             9.0            123.7
# 2024-01-16            808.4            36.4             89.6
# 2024-01-17            732.6            15.2            120.1
# 2024-01-18            702.7            25.3             61.4
# 2024-01-19            900.3            20.3            119.5
#
#             Dinner_Proteines  Lunch_Calories  Lunch_Lipides  Lunch_Glucides  \
# Date
# 2020-08-03              17.1           656.0           41.4            26.6
# 2020-08-04              28.5           433.7           16.6            60.6
# 2020-08-05              14.8           638.0           25.8            62.8
# 2020-08-06              11.8           388.9           15.6            30.3
# 2020-08-07               7.9           484.6           24.8             1.9
# ...                      ...             ...            ...             ...
# 2024-01-15              56.4           882.8           12.5            62.6
# 2024-01-16              35.3           847.2           20.4            63.7
# 2024-01-17              41.0           904.6           14.3            54.5
# 2024-01-18              48.6             NaN            NaN             NaN
# 2024-01-19              68.1           770.7           17.2            34.0
#
#             Lunch_Proteines  Snacks_Calories  Snacks_Lipides  Snacks_Glucides  \
# Date
# 2020-08-03             33.5             58.0             0.0             14.0
# 2020-08-04             15.6              NaN             NaN              NaN
# 2020-08-05             36.4              NaN             NaN              NaN
# 2020-08-06             22.4              NaN             NaN              NaN
# 2020-08-07             60.0              NaN             NaN              NaN
# ...                     ...              ...             ...              ...
# 2024-01-15            133.5              NaN             NaN              NaN
# 2024-01-16            106.4              NaN             NaN              NaN
# 2024-01-17            142.0              NaN             NaN              NaN
# 2024-01-18              NaN              NaN             NaN              NaN
# 2024-01-19            119.7              NaN             NaN              NaN
#
#             Snacks_Proteines
# Date
# 2020-08-03               0.0
# 2020-08-04               NaN
# 2020-08-05               NaN
# 2020-08-06               NaN
# 2020-08-07               NaN
# ...                      ...
# 2024-01-15               NaN
# 2024-01-16               NaN
# 2024-01-17               NaN
# 2024-01-18               NaN
# 2024-01-19               NaN
#
# [1265 rows x 20 columns]

# %% [markdown]
# ### Exercice

# %%
def extract_data_training(exo_dict):
    # utility fonction pour récupérer : date, durée, type exercice et calories dépensées
    
    # récupère date
    pattern = '2(\d){3,3}-(\d){2,2}-(\d){2,2}'  # on cherche une date du type 2xxx-yy-zz
    p = re.compile(pattern)
    m = p.search(exo_dict.get('startTime'))
    if m: 
        time_format = '%Y-%m-%d'
        exo_date = datetime.datetime.strptime( exo_dict.get('startTime')[:10], time_format ).date()
    
    # récupère durée
    pattern = '(\d)+[.]?(\d)*'  # on cherche une durée du type xxxx.yyyy
    p = re.compile(pattern)
    m = p.search(exo_dict.get('duration'))
    if m:
        exo_duration = float(m.group())
    
    # récupère type activité et calories dépensées
    d = exo_dict.get('exercises')[0]   
    exo_type = d.get('sport')
    if d.get('kiloCalories'):
        exo_cals = float(d.get('kiloCalories'))
    else:
        exo_cals = 0.0
    
    return exo_date, exo_duration, exo_type, exo_cals

# %%
# Récupère les données EXERCICE

polar_filename = import_pathname + "polar"  # données de Polar

with ZipFile(polar_filename, 'r') as polar_zip:
    output_dir = polar_zip.namelist()
    
    target = 'training-session'
    list_all_exos = []
    for i, enr_name in enumerate(tqdm(output_dir)): # on parcourt la liste des archives
        if enr_name[:len(target)] == target:  # si c'est un enregistrement d'une session de training, on traite
            enr_json = polar_zip.extract(enr_name, path=import_pathname)   # extraction du json
            with open(enr_json, 'r') as f:
                exo_dict = json.load(f)
                exo_date, exo_duration, exo_type, exo_cals = extract_data_training(exo_dict)
                list_all_exos.append([exo_date, exo_type, exo_duration, exo_cals])
                # if dict_all_exos.get(exo_date) == None:
                #     dict_all_exos[exo_date] = [ exo_duration, exo_cals]
                # else:
                #     dict_all_exos[exo_date] = [ dict_all_exos[exo_date][0] + exo_duration, dict_all_exos[exo_date][1] + exo_cals ]
                # # print(f'exercice {i+1} : date = {exo_date}, durée = {exo_duration}, type = {exo_type}, cals = {exo_cals}')
            os.remove(enr_json)
# Out:
# 100%|██████████| 1828/1828 [00:54<00:00, 33.59it/s]

# %%
col_names = ['Date', 'exo_type', 'exo_secondes', 'exo_cals_bruts']
df_exos = pd.DataFrame(list_all_exos, columns=col_names)

# %%
df_exos
# Out:
#             Date           exo_type  exo_secondes  exo_cals_bruts
# 0     2022-05-23  STRENGTH_TRAINING      2040.749           265.0
# 1     2023-08-20  STRENGTH_TRAINING      5220.729           442.0
# 2     2023-09-27      INDOOR_ROWING      3660.599           277.0
# 3     2022-12-26  STRENGTH_TRAINING      4260.740           598.0
# 4     2023-04-03            WALKING      4122.586           451.0
# ...          ...                ...           ...             ...
# 1008  2022-12-08            WALKING       809.472           127.0
# 1009  2022-06-24      INDOOR_ROWING      1020.720           189.0
# 1010  2022-03-08      INDOOR_ROWING      1902.093           260.0
# 1011  2021-04-06  STRENGTH_TRAINING      3002.443           205.0
# 1012  2022-06-24  STRENGTH_TRAINING      5400.596           357.0
#
# [1013 rows x 4 columns]

# %%
df_exercices = df_exos.groupby('Date').sum(numeric_only=True)

# %%
df_exercices
# Out:
#             exo_secondes  exo_cals_bruts
# Date
# 2021-03-29      3220.826           328.0
# 2021-03-30      2818.678           449.0
# 2021-03-31      3186.236           272.0
# 2021-04-03      3436.335           344.0
# 2021-04-04      2682.132           494.0
# ...                  ...             ...
# 2023-12-31      6005.953           671.0
# 2024-01-03      3128.453           251.0
# 2024-01-04      1621.203           245.0
# 2024-01-05      2220.597           202.0
# 2024-01-07      3240.580           291.0
#
# [753 rows x 2 columns]

# %%
exo_types=list(df_exos['exo_type'].unique())

data_names=['exo_secondes', 'exo_cals_bruts']
col_names=['Date'] + data_names

for exo_type in exo_types:
    df_to_add = df_exos[df_exos['exo_type']==exo_type][col_names].groupby('Date').sum()
    mapping_data_names = { data_name : exo_type + '_' + data_name for data_name in data_names }
    df_to_add.rename(columns=mapping_data_names, inplace=True)
    df_exercices = pd.concat([df_exercices, df_to_add], axis=1)

# %%
df_exercices
# Out:
#             exo_secondes  exo_cals_bruts  STRENGTH_TRAINING_exo_secondes  \
# Date
# 2021-03-29      3220.826           328.0                        3220.826
# 2021-03-30      2818.678           449.0                             NaN
# 2021-03-31      3186.236           272.0                        3186.236
# 2021-04-03      3436.335           344.0                        3436.335
# 2021-04-04      2682.132           494.0                             NaN
# ...                  ...             ...                             ...
# 2023-12-31      6005.953           671.0                        6005.953
# 2024-01-03      3128.453           251.0                        3128.453
# 2024-01-04      1621.203           245.0                             NaN
# 2024-01-05      2220.597           202.0                        2220.597
# 2024-01-07      3240.580           291.0                        3240.580
#
#             STRENGTH_TRAINING_exo_cals_bruts  INDOOR_ROWING_exo_secondes  \
# Date
# 2021-03-29                             328.0                         NaN
# 2021-03-30                               NaN                         NaN
# 2021-03-31                             272.0                         NaN
# 2021-04-03                             344.0                         NaN
# 2021-04-04                               NaN                         NaN
# ...                                      ...                         ...
# 2023-12-31                             671.0                         NaN
# 2024-01-03                             251.0                         NaN
# 2024-01-04                               NaN                    1621.203
# 2024-01-05                             202.0                         NaN
# 2024-01-07                             291.0                         NaN
#
#             INDOOR_ROWING_exo_cals_bruts  WALKING_exo_secondes  \
# Date
# 2021-03-29                           NaN                   NaN
# 2021-03-30                           NaN                   NaN
# 2021-03-31                           NaN                   NaN
# 2021-04-03                           NaN                   NaN
# 2021-04-04                           NaN                   NaN
# ...                                  ...                   ...
# 2023-12-31                           NaN                   NaN
# 2024-01-03                           NaN                   NaN
# 2024-01-04                         245.0                   NaN
# 2024-01-05                           NaN                   NaN
# 2024-01-07                           NaN                   NaN
#
#             WALKING_exo_cals_bruts  BOXING_exo_secondes  \
# Date
# 2021-03-29                     NaN                  NaN
# 2021-03-30                     NaN                  NaN
# 2021-03-31                     NaN                  NaN
# 2021-04-03                     NaN                  NaN
# 2021-04-04                     NaN                  NaN
# ...                            ...                  ...
# 2023-12-31                     NaN                  NaN
# 2024-01-03                     NaN                  NaN
# 2024-01-04                     NaN                  NaN
# 2024-01-05                     NaN                  NaN
# 2024-01-07                     NaN                  NaN
#
#             BOXING_exo_cals_bruts  ...  CROSS-COUNTRY_SKIING_exo_secondes  \
# Date                               ...
# 2021-03-29                    NaN  ...                                NaN
# 2021-03-30                    NaN  ...                                NaN
# 2021-03-31                    NaN  ...                                NaN
# 2021-04-03                    NaN  ...                                NaN
# 2021-04-04                    NaN  ...                                NaN
# ...                           ...  ...                                ...
# 2023-12-31                    NaN  ...                                NaN
# 2024-01-03                    NaN  ...                                NaN
# 2024-01-04                    NaN  ...                                NaN
# 2024-01-05                    NaN  ...                                NaN
# 2024-01-07                    NaN  ...                                NaN
#
#             CROSS-COUNTRY_SKIING_exo_cals_bruts  ROWING_exo_secondes  \
# Date
# 2021-03-29                                  NaN                  NaN
# 2021-03-30                                  NaN                  NaN
# 2021-03-31                                  NaN                  NaN
# 2021-04-03                                  NaN                  NaN
# 2021-04-04                                  NaN                  NaN
# ...                                         ...                  ...
# 2023-12-31                                  NaN                  NaN
# 2024-01-03                                  NaN                  NaN
# 2024-01-04                                  NaN                  NaN
# 2024-01-05                                  NaN                  NaN
# 2024-01-07                                  NaN                  NaN
#
#             ROWING_exo_cals_bruts  TREADMILL_RUNNING_exo_secondes  \
# Date
# 2021-03-29                    NaN                             NaN
# 2021-03-30                    NaN                             NaN
# 2021-03-31                    NaN                             NaN
# 2021-04-03                    NaN                             NaN
# 2021-04-04                    NaN                             NaN
# ...                           ...                             ...
# 2023-12-31                    NaN                             NaN
# 2024-01-03                    NaN                             NaN
# 2024-01-04                    NaN                             NaN
# 2024-01-05                    NaN                             NaN
# 2024-01-07                    NaN                             NaN
#
#             TREADMILL_RUNNING_exo_cals_bruts  SWIMMING_exo_secondes  \
# Date
# 2021-03-29                               NaN                    NaN
# 2021-03-30                               NaN                    NaN
# 2021-03-31                               NaN                    NaN
# 2021-04-03                               NaN                    NaN
# 2021-04-04                               NaN                    NaN
# ...                                      ...                    ...
# 2023-12-31                               NaN                    NaN
# 2024-01-03                               NaN                    NaN
# 2024-01-04                               NaN                    NaN
# 2024-01-05                               NaN                    NaN
# 2024-01-07                               NaN                    NaN
#
#             SWIMMING_exo_cals_bruts  DOWNHILL_SKIING_exo_secondes  \
# Date
# 2021-03-29                      NaN                           NaN
# 2021-03-30                      NaN                           NaN
# 2021-03-31                      NaN                           NaN
# 2021-04-03                      NaN                           NaN
# 2021-04-04                      NaN                           NaN
# ...                             ...                           ...
# 2023-12-31                      NaN                           NaN
# 2024-01-03                      NaN                           NaN
# 2024-01-04                      NaN                           NaN
# 2024-01-05                      NaN                           NaN
# 2024-01-07                      NaN                           NaN
#
#             DOWNHILL_SKIING_exo_cals_bruts
# Date
# 2021-03-29                             NaN
# 2021-03-30                             NaN
# 2021-03-31                             NaN
# 2021-04-03                             NaN
# 2021-04-04                             NaN
# ...                                    ...
# 2023-12-31                             NaN
# 2024-01-03                             NaN
# 2024-01-04                             NaN
# 2024-01-05                             NaN
# 2024-01-07                             NaN
#
# [753 rows x 24 columns]

# %%
df_exercices.describe(include='all').transpose()
# Out:
#                                      count          mean          std  \
# exo_secondes                         753.0   4440.830564  2305.557219
# exo_cals_bruts                       753.0    485.288181   230.554819
# STRENGTH_TRAINING_exo_secondes       463.0   4442.945769  1445.718277
# STRENGTH_TRAINING_exo_cals_bruts     463.0    422.788337   168.704776
# INDOOR_ROWING_exo_secondes           302.0   2377.935281  1256.600346
# INDOOR_ROWING_exo_cals_bruts         302.0    383.817881   208.391140
# WALKING_exo_secondes                  83.0   4971.983904  3820.032777
# WALKING_exo_cals_bruts                83.0    429.361446   316.497508
# BOXING_exo_secondes                    4.0   1199.985750   375.262873
# BOXING_exo_cals_bruts                  4.0    168.000000    54.080187
# RUNNING_exo_secondes                  22.0   1686.925409   414.405485
# RUNNING_exo_cals_bruts                22.0    235.772727    67.779707
# JOGGING_exo_secondes                  21.0   3009.026714  1261.424581
# JOGGING_exo_cals_bruts                21.0    454.285714   229.477045
# CROSS-COUNTRY_SKIING_exo_secondes      2.0  11771.716000  2444.907963
# CROSS-COUNTRY_SKIING_exo_cals_bruts    2.0    767.500000   154.856385
# ROWING_exo_secondes                    1.0   1876.669000          NaN
# ROWING_exo_cals_bruts                  1.0    285.000000          NaN
# TREADMILL_RUNNING_exo_secondes         1.0   2113.078000          NaN
# TREADMILL_RUNNING_exo_cals_bruts       1.0    258.000000          NaN
# SWIMMING_exo_secondes                  1.0    600.000000          NaN
# SWIMMING_exo_cals_bruts                1.0     50.000000          NaN
# DOWNHILL_SKIING_exo_secondes           2.0  11407.681500  5131.915853
# DOWNHILL_SKIING_exo_cals_bruts         2.0    297.000000   182.433550
#
#                                            min          25%         50%  \
# exo_secondes                           900.000   2776.74100   4140.7130
# exo_cals_bruts                           0.000    315.00000    450.0000
# STRENGTH_TRAINING_exo_secondes         780.713   3375.65450   4620.7360
# STRENGTH_TRAINING_exo_cals_bruts        48.000    304.00000    411.0000
# INDOOR_ROWING_exo_secondes             194.716   1760.71175   2100.7160
# INDOOR_ROWING_exo_cals_bruts            18.000    269.25000    340.0000
# WALKING_exo_secondes                   437.735   2430.72750   3840.0000
# WALKING_exo_cals_bruts                   0.000    180.00000    347.0000
# BOXING_exo_secondes                    900.704    990.70325   1077.4065
# BOXING_exo_cals_bruts                  113.000    137.00000    159.5000
# RUNNING_exo_secondes                   283.484   1701.22050   1742.1135
# RUNNING_exo_cals_bruts                  48.000    218.75000    238.0000
# JOGGING_exo_secondes                  1317.171   1931.72200   2753.5750
# JOGGING_exo_cals_bruts                  59.000    290.00000    469.0000
# CROSS-COUNTRY_SKIING_exo_secondes    10042.905  10907.31050  11771.7160
# CROSS-COUNTRY_SKIING_exo_cals_bruts    658.000    712.75000    767.5000
# ROWING_exo_secondes                   1876.669   1876.66900   1876.6690
# ROWING_exo_cals_bruts                  285.000    285.00000    285.0000
# TREADMILL_RUNNING_exo_secondes        2113.078   2113.07800   2113.0780
# TREADMILL_RUNNING_exo_cals_bruts       258.000    258.00000    258.0000
# SWIMMING_exo_secondes                  600.000    600.00000    600.0000
# SWIMMING_exo_cals_bruts                 50.000     50.00000     50.0000
# DOWNHILL_SKIING_exo_secondes          7778.869   9593.27525  11407.6815
# DOWNHILL_SKIING_exo_cals_bruts         168.000    232.50000    297.0000
#
#                                              75%        max
# exo_secondes                          5734.30100  28800.000
# exo_cals_bruts                         609.00000   2290.000
# STRENGTH_TRAINING_exo_secondes        5296.72000   8762.855
# STRENGTH_TRAINING_exo_cals_bruts       531.00000   1099.000
# INDOOR_ROWING_exo_secondes            2837.21275  13800.740
# INDOOR_ROWING_exo_cals_bruts           488.75000   2290.000
# WALKING_exo_secondes                  7516.41550  28800.000
# WALKING_exo_cals_bruts                 619.00000   1243.000
# BOXING_exo_secondes                   1286.68900   1744.426
# BOXING_exo_cals_bruts                  190.50000    240.000
# RUNNING_exo_secondes                  1795.34750   2818.678
# RUNNING_exo_cals_bruts                 247.25000    449.000
# JOGGING_exo_secondes                  3635.25000   6108.884
# JOGGING_exo_cals_bruts                 568.00000    842.000
# CROSS-COUNTRY_SKIING_exo_secondes    12636.12150  13500.527
# CROSS-COUNTRY_SKIING_exo_cals_bruts    822.25000    877.000
# ROWING_exo_secondes                   1876.66900   1876.669
# ROWING_exo_cals_bruts                  285.00000    285.000
# TREADMILL_RUNNING_exo_secondes        2113.07800   2113.078
# TREADMILL_RUNNING_exo_cals_bruts       258.00000    258.000
# SWIMMING_exo_secondes                  600.00000    600.000
# SWIMMING_exo_cals_bruts                 50.00000     50.000
# DOWNHILL_SKIING_exo_secondes         13222.08775  15036.494
# DOWNHILL_SKIING_exo_cals_bruts         361.50000    426.000

# %% [markdown]
# ### Full Dataset

# %%
dataset = pd.concat([df_weight, df_food, df_exercices], axis=1).sort_index()

# %%
dataset
# Out:
#             Masse_Totale  Masse_Grasse  Masse_Osseuse  Masse_Musculaire  \
# Date
# 2001-01-01     72.000000     12.060000       3.000000         56.930000
# 2010-10-29     94.750000     22.325000            NaN               NaN
# 2010-10-30     93.216667     20.976667            NaN               NaN
# 2010-10-31     92.675000     23.385000            NaN               NaN
# 2010-11-01     92.950000     22.210000            NaN               NaN
# ...                  ...           ...            ...               ...
# 2024-01-16     72.593333     12.503333       3.002500         57.072500
# 2024-01-17     72.378462     12.340769       3.000000         57.022308
# 2024-01-18     73.055000     12.607500       3.020000         57.414167
# 2024-01-19     72.494167     12.419167       3.002500         57.056667
# 2024-01-20     72.846667     12.586667       3.010833         57.232500
#
#             Masse_Hydrique       MG%          BMR  std_Masse_Totale  \
# Date
# 2001-01-01       40.060000  0.167500  1664.704000               NaN
# 2010-10-29             NaN  0.235566  1934.380000          0.707107
# 2010-10-30             NaN  0.225046  1930.384000          0.057735
# 2010-10-31             NaN  0.252336  1866.664000          0.035355
# 2010-11-01             NaN  0.238946  1897.984000               NaN
# ...                    ...       ...          ...               ...
# 2024-01-16       40.121667  0.172237  1667.944000          0.139306
# 2024-01-17       40.098462  0.170503  1666.814154          0.026409
# 2024-01-18       40.441667  0.172574  1675.666000          0.135210
# 2024-01-19       40.122500  0.171311  1667.620000          0.158714
# 2024-01-20       40.268333  0.172782  1671.616000          0.094131
#
#             std_Masse_Grasse  std_Masse_Osseuse  ...  \
# Date                                             ...
# 2001-01-01               NaN                NaN  ...
# 2010-10-29          1.548564                NaN  ...
# 2010-10-30          6.509780                NaN  ...
# 2010-10-31          1.279863                NaN  ...
# 2010-11-01               NaN                NaN  ...
# ...                      ...                ...  ...
# 2024-01-16          0.080941           0.006216  ...
# 2024-01-17          0.054842           0.000000  ...
# 2024-01-18          0.091266           0.006030  ...
# 2024-01-19          0.107319           0.004523  ...
# 2024-01-20          0.066788           0.002887  ...
#
#             CROSS-COUNTRY_SKIING_exo_secondes  \
# Date
# 2001-01-01                                NaN
# 2010-10-29                                NaN
# 2010-10-30                                NaN
# 2010-10-31                                NaN
# 2010-11-01                                NaN
# ...                                       ...
# 2024-01-16                                NaN
# 2024-01-17                                NaN
# 2024-01-18                                NaN
# 2024-01-19                                NaN
# 2024-01-20                                NaN
#
#             CROSS-COUNTRY_SKIING_exo_cals_bruts  ROWING_exo_secondes  \
# Date
# 2001-01-01                                  NaN                  NaN
# 2010-10-29                                  NaN                  NaN
# 2010-10-30                                  NaN                  NaN
# 2010-10-31                                  NaN                  NaN
# 2010-11-01                                  NaN                  NaN
# ...                                         ...                  ...
# 2024-01-16                                  NaN                  NaN
# 2024-01-17                                  NaN                  NaN
# 2024-01-18                                  NaN                  NaN
# 2024-01-19                                  NaN                  NaN
# 2024-01-20                                  NaN                  NaN
#
#             ROWING_exo_cals_bruts  TREADMILL_RUNNING_exo_secondes  \
# Date
# 2001-01-01                    NaN                             NaN
# 2010-10-29                    NaN                             NaN
# 2010-10-30                    NaN                             NaN
# 2010-10-31                    NaN                             NaN
# 2010-11-01                    NaN                             NaN
# ...                           ...                             ...
# 2024-01-16                    NaN                             NaN
# 2024-01-17                    NaN                             NaN
# 2024-01-18                    NaN                             NaN
# 2024-01-19                    NaN                             NaN
# 2024-01-20                    NaN                             NaN
#
#             TREADMILL_RUNNING_exo_cals_bruts  SWIMMING_exo_secondes  \
# Date
# 2001-01-01                               NaN                    NaN
# 2010-10-29                               NaN                    NaN
# 2010-10-30                               NaN                    NaN
# 2010-10-31                               NaN                    NaN
# 2010-11-01                               NaN                    NaN
# ...                                      ...                    ...
# 2024-01-16                               NaN                    NaN
# 2024-01-17                               NaN                    NaN
# 2024-01-18                               NaN                    NaN
# 2024-01-19                               NaN                    NaN
# 2024-01-20                               NaN                    NaN
#
#             SWIMMING_exo_cals_bruts  DOWNHILL_SKIING_exo_secondes  \
# Date
# 2001-01-01                      NaN                           NaN
# 2010-10-29                      NaN                           NaN
# 2010-10-30                      NaN                           NaN
# 2010-10-31                      NaN                           NaN
# 2010-11-01                      NaN                           NaN
# ...                             ...                           ...
# 2024-01-16                      NaN                           NaN
# 2024-01-17                      NaN                           NaN
# 2024-01-18                      NaN                           NaN
# 2024-01-19                      NaN                           NaN
# 2024-01-20                      NaN                           NaN
#
#             DOWNHILL_SKIING_exo_cals_bruts
# Date
# 2001-01-01                             NaN
# 2010-10-29                             NaN
# 2010-10-30                             NaN
# 2010-10-31                             NaN
# 2010-11-01                             NaN
# ...                                    ...
# 2024-01-16                             NaN
# 2024-01-17                             NaN
# 2024-01-18                             NaN
# 2024-01-19                             NaN
# 2024-01-20                             NaN
#
# [1482 rows x 58 columns]

# %% [markdown]
# ### Nettoyage

# %%
# time cutoff

start_date = datetime.date(2020, 9, 1)
dataset = dataset[dataset.index >= start_date]

# %%
dataset
# Out:
#             Masse_Totale  Masse_Grasse  Masse_Osseuse  Masse_Musculaire  \
# Date
# 2020-09-01    101.250000     33.020000            NaN               NaN
# 2020-09-02    101.150000     31.945000            NaN               NaN
# 2020-09-03    101.200000     30.930000            NaN               NaN
# 2020-09-04    100.800000     29.460000            NaN               NaN
# 2020-09-05    100.600000     31.450000            NaN               NaN
# ...                  ...           ...            ...               ...
# 2024-01-16     72.593333     12.503333       3.002500         57.072500
# 2024-01-17     72.378462     12.340769       3.000000         57.022308
# 2024-01-18     73.055000     12.607500       3.020000         57.414167
# 2024-01-19     72.494167     12.419167       3.002500         57.056667
# 2024-01-20     72.846667     12.586667       3.010833         57.232500
#
#             Masse_Hydrique       MG%          BMR  std_Masse_Totale  \
# Date
# 2020-09-01             NaN  0.326123  1843.768000               NaN
# 2020-09-02             NaN  0.315818  1864.828000          0.000000
# 2020-09-03             NaN  0.305632  1887.832000               NaN
# 2020-09-04             NaN  0.292262  1910.944000               NaN
# 2020-09-05             NaN  0.312624  1863.640000               NaN
# ...                    ...       ...          ...               ...
# 2024-01-16       40.121667  0.172237  1667.944000          0.139306
# 2024-01-17       40.098462  0.170503  1666.814154          0.026409
# 2024-01-18       40.441667  0.172574  1675.666000          0.135210
# 2024-01-19       40.122500  0.171311  1667.620000          0.158714
# 2024-01-20       40.268333  0.172782  1671.616000          0.094131
#
#             std_Masse_Grasse  std_Masse_Osseuse  ...  \
# Date                                             ...
# 2020-09-01               NaN                NaN  ...
# 2020-09-02          0.106066                NaN  ...
# 2020-09-03               NaN                NaN  ...
# 2020-09-04               NaN                NaN  ...
# 2020-09-05               NaN                NaN  ...
# ...                      ...                ...  ...
# 2024-01-16          0.080941           0.006216  ...
# 2024-01-17          0.054842           0.000000  ...
# 2024-01-18          0.091266           0.006030  ...
# 2024-01-19          0.107319           0.004523  ...
# 2024-01-20          0.066788           0.002887  ...
#
#             CROSS-COUNTRY_SKIING_exo_secondes  \
# Date
# 2020-09-01                                NaN
# 2020-09-02                                NaN
# 2020-09-03                                NaN
# 2020-09-04                                NaN
# 2020-09-05                                NaN
# ...                                       ...
# 2024-01-16                                NaN
# 2024-01-17                                NaN
# 2024-01-18                                NaN
# 2024-01-19                                NaN
# 2024-01-20                                NaN
#
#             CROSS-COUNTRY_SKIING_exo_cals_bruts  ROWING_exo_secondes  \
# Date
# 2020-09-01                                  NaN                  NaN
# 2020-09-02                                  NaN                  NaN
# 2020-09-03                                  NaN                  NaN
# 2020-09-04                                  NaN                  NaN
# 2020-09-05                                  NaN                  NaN
# ...                                         ...                  ...
# 2024-01-16                                  NaN                  NaN
# 2024-01-17                                  NaN                  NaN
# 2024-01-18                                  NaN                  NaN
# 2024-01-19                                  NaN                  NaN
# 2024-01-20                                  NaN                  NaN
#
#             ROWING_exo_cals_bruts  TREADMILL_RUNNING_exo_secondes  \
# Date
# 2020-09-01                    NaN                             NaN
# 2020-09-02                    NaN                             NaN
# 2020-09-03                    NaN                             NaN
# 2020-09-04                    NaN                             NaN
# 2020-09-05                    NaN                             NaN
# ...                           ...                             ...
# 2024-01-16                    NaN                             NaN
# 2024-01-17                    NaN                             NaN
# 2024-01-18                    NaN                             NaN
# 2024-01-19                    NaN                             NaN
# 2024-01-20                    NaN                             NaN
#
#             TREADMILL_RUNNING_exo_cals_bruts  SWIMMING_exo_secondes  \
# Date
# 2020-09-01                               NaN                    NaN
# 2020-09-02                               NaN                    NaN
# 2020-09-03                               NaN                    NaN
# 2020-09-04                               NaN                    NaN
# 2020-09-05                               NaN                    NaN
# ...                                      ...                    ...
# 2024-01-16                               NaN                    NaN
# 2024-01-17                               NaN                    NaN
# 2024-01-18                               NaN                    NaN
# 2024-01-19                               NaN                    NaN
# 2024-01-20                               NaN                    NaN
#
#             SWIMMING_exo_cals_bruts  DOWNHILL_SKIING_exo_secondes  \
# Date
# 2020-09-01                      NaN                           NaN
# 2020-09-02                      NaN                           NaN
# 2020-09-03                      NaN                           NaN
# 2020-09-04                      NaN                           NaN
# 2020-09-05                      NaN                           NaN
# ...                             ...                           ...
# 2024-01-16                      NaN                           NaN
# 2024-01-17                      NaN                           NaN
# 2024-01-18                      NaN                           NaN
# 2024-01-19                      NaN                           NaN
# 2024-01-20                      NaN                           NaN
#
#             DOWNHILL_SKIING_exo_cals_bruts
# Date
# 2020-09-01                             NaN
# 2020-09-02                             NaN
# 2020-09-03                             NaN
# 2020-09-04                             NaN
# 2020-09-05                             NaN
# ...                                    ...
# 2024-01-16                             NaN
# 2024-01-17                             NaN
# 2024-01-18                             NaN
# 2024-01-19                             NaN
# 2024-01-20                             NaN
#
# [1237 rows x 58 columns]

# %%
dataset.describe(include='all').transpose()
# Out:
#                                       count          mean          std  \
# Masse_Totale                         1228.0     73.375685     7.106499
# Masse_Grasse                         1228.0     11.928024     4.650001
# Masse_Osseuse                         322.0      3.033345     0.059992
# Masse_Musculaire                      322.0     57.500714     0.962663
# Masse_Hydrique                        322.0     40.825200     1.127273
# MG%                                  1228.0      0.158741     0.040631
# BMR                                  1228.0   1697.269482    55.846954
# std_Masse_Totale                     1212.0      0.069255     0.046173
# std_Masse_Grasse                     1212.0      0.085519     0.072286
# std_Masse_Osseuse                     321.0      0.004754     0.003839
# std_Masse_Musculaire                  321.0      0.067721     0.042138
# std_Masse_Hydrique                    321.0      0.076316     0.061348
# std_MG%                              1212.0      0.001055     0.000739
# std_BMR                              1212.0      1.711919     1.564701
# Calories                             1236.0   1970.543285   461.211454
# Lipides                              1236.0     52.820955    22.404283
# Glucides                             1236.0    213.355987    76.036361
# Proteines                            1236.0    157.567314    39.316201
# Breakfast_Calories                    956.0    610.453766   214.756952
# Breakfast_Lipides                     956.0     17.298431     9.845794
# Breakfast_Glucides                    956.0     63.228766    29.607690
# Breakfast_Proteines                   956.0     53.728975    28.931699
# Dinner_Calories                      1221.0    735.047011   394.317921
# Dinner_Lipides                       1221.0     19.814660    16.045447
# Dinner_Glucides                      1221.0     91.793038    62.570068
# Dinner_Proteines                     1221.0     42.394021    24.045250
# Lunch_Calories                       1219.0    763.600738   363.400128
# Lunch_Lipides                        1219.0     19.447498    14.467619
# Lunch_Glucides                       1219.0     71.944791    51.837945
# Lunch_Proteines                      1219.0     74.650041    33.988300
# Snacks_Calories                       190.0    124.610526   233.942670
# Snacks_Lipides                        190.0      4.469474    12.252650
# Snacks_Glucides                       190.0     18.322632    29.898126
# Snacks_Proteines                      190.0      3.298947     4.967332
# exo_secondes                          753.0   4440.830564  2305.557219
# exo_cals_bruts                        753.0    485.288181   230.554819
# STRENGTH_TRAINING_exo_secondes        463.0   4442.945769  1445.718277
# STRENGTH_TRAINING_exo_cals_bruts      463.0    422.788337   168.704776
# INDOOR_ROWING_exo_secondes            302.0   2377.935281  1256.600346
# INDOOR_ROWING_exo_cals_bruts          302.0    383.817881   208.391140
# WALKING_exo_secondes                   83.0   4971.983904  3820.032777
# WALKING_exo_cals_bruts                 83.0    429.361446   316.497508
# BOXING_exo_secondes                     4.0   1199.985750   375.262873
# BOXING_exo_cals_bruts                   4.0    168.000000    54.080187
# RUNNING_exo_secondes                   22.0   1686.925409   414.405485
# RUNNING_exo_cals_bruts                 22.0    235.772727    67.779707
# JOGGING_exo_secondes                   21.0   3009.026714  1261.424581
# JOGGING_exo_cals_bruts                 21.0    454.285714   229.477045
# CROSS-COUNTRY_SKIING_exo_secondes       2.0  11771.716000  2444.907963
# CROSS-COUNTRY_SKIING_exo_cals_bruts     2.0    767.500000   154.856385
# ROWING_exo_secondes                     1.0   1876.669000          NaN
# ROWING_exo_cals_bruts                   1.0    285.000000          NaN
# TREADMILL_RUNNING_exo_secondes          1.0   2113.078000          NaN
# TREADMILL_RUNNING_exo_cals_bruts        1.0    258.000000          NaN
# SWIMMING_exo_secondes                   1.0    600.000000          NaN
# SWIMMING_exo_cals_bruts                 1.0     50.000000          NaN
# DOWNHILL_SKIING_exo_secondes            2.0  11407.681500  5131.915853
# DOWNHILL_SKIING_exo_cals_bruts          2.0    297.000000   182.433550
#
#                                               min           25%           50%  \
# Masse_Totale                            66.000000     69.232500     71.284286
# Masse_Grasse                             7.541667      8.925937     10.778125
# Masse_Osseuse                            2.934286      2.997500      3.019583
# Masse_Musculaire                        55.700000     56.885972     57.317333
# Masse_Hydrique                          38.921429     40.121875     40.557500
# MG%                                      0.112927      0.128734      0.150843
# BMR                                   1626.348571   1663.960000   1678.711000
# std_Masse_Totale                         0.000000      0.037796      0.056045
# std_Masse_Grasse                         0.000000      0.054744      0.073824
# std_Masse_Osseuse                        0.000000      0.003780      0.004880
# std_Masse_Musculaire                     0.009910      0.050122      0.065522
# std_Masse_Hydrique                       0.013887      0.055377      0.070848
# std_MG%                                  0.000054      0.000712      0.000954
# std_BMR                                  0.000000      1.089676      1.436703
# Calories                                 0.300000   1781.475000   1851.200000
# Lipides                                  0.000000     38.600000     49.300000
# Glucides                                 0.100000    168.675000    199.100000
# Proteines                                0.000000    134.600000    161.950000
# Breakfast_Calories                       0.300000    535.325000    600.500000
# Breakfast_Lipides                        0.000000      9.550000     16.500000
# Breakfast_Glucides                       0.000000     42.950000     63.700000
# Breakfast_Proteines                      0.000000     28.275000     58.050000
# Dinner_Calories                          0.300000    514.700000    648.100000
# Dinner_Lipides                           0.000000      9.400000     16.100000
# Dinner_Glucides                          0.000000     52.800000     80.200000
# Dinner_Proteines                         0.000000     25.900000     38.600000
# Lunch_Calories                           0.300000    580.450000    700.900000
# Lunch_Lipides                            0.000000     10.150000     16.700000
# Lunch_Glucides                           0.100000     44.150000     63.200000
# Lunch_Proteines                          0.000000     52.700000     70.400000
# Snacks_Calories                          0.000000     29.225000     58.900000
# Snacks_Lipides                           0.000000      0.300000      1.100000
# Snacks_Glucides                          0.000000      3.800000      9.300000
# Snacks_Proteines                         0.000000      0.500000      1.050000
# exo_secondes                           900.000000   2776.741000   4140.713000
# exo_cals_bruts                           0.000000    315.000000    450.000000
# STRENGTH_TRAINING_exo_secondes         780.713000   3375.654500   4620.736000
# STRENGTH_TRAINING_exo_cals_bruts        48.000000    304.000000    411.000000
# INDOOR_ROWING_exo_secondes             194.716000   1760.711750   2100.716000
# INDOOR_ROWING_exo_cals_bruts            18.000000    269.250000    340.000000
# WALKING_exo_secondes                   437.735000   2430.727500   3840.000000
# WALKING_exo_cals_bruts                   0.000000    180.000000    347.000000
# BOXING_exo_secondes                    900.704000    990.703250   1077.406500
# BOXING_exo_cals_bruts                  113.000000    137.000000    159.500000
# RUNNING_exo_secondes                   283.484000   1701.220500   1742.113500
# RUNNING_exo_cals_bruts                  48.000000    218.750000    238.000000
# JOGGING_exo_secondes                  1317.171000   1931.722000   2753.575000
# JOGGING_exo_cals_bruts                  59.000000    290.000000    469.000000
# CROSS-COUNTRY_SKIING_exo_secondes    10042.905000  10907.310500  11771.716000
# CROSS-COUNTRY_SKIING_exo_cals_bruts    658.000000    712.750000    767.500000
# ROWING_exo_secondes                   1876.669000   1876.669000   1876.669000
# ROWING_exo_cals_bruts                  285.000000    285.000000    285.000000
# TREADMILL_RUNNING_exo_secondes        2113.078000   2113.078000   2113.078000
# TREADMILL_RUNNING_exo_cals_bruts       258.000000    258.000000    258.000000
# SWIMMING_exo_secondes                  600.000000    600.000000    600.000000
# SWIMMING_exo_cals_bruts                 50.000000     50.000000     50.000000
# DOWNHILL_SKIING_exo_secondes          7778.869000   9593.275250  11407.681500
# DOWNHILL_SKIING_exo_cals_bruts         168.000000    232.500000    297.000000
#
#                                               75%           max
# Masse_Totale                            73.167857    101.250000
# Masse_Grasse                            11.992364     33.020000
# Masse_Osseuse                            3.056500      3.400000
# Masse_Musculaire                        57.932500     61.840000
# Masse_Hydrique                          41.284152     47.900000
# MG%                                      0.165863      0.326123
# BMR                                   1704.623500   1917.928000
# std_Masse_Totale                         0.089423      0.588509
# std_Masse_Grasse                         0.095562      1.036352
# std_Masse_Osseuse                        0.005345      0.063631
# std_Masse_Musculaire                     0.079042      0.716210
# std_Masse_Hydrique                       0.086814      1.072184
# std_MG%                                  0.001207      0.010429
# std_BMR                                  1.864369     21.686945
# Calories                              2048.350000   5762.000000
# Lipides                                 63.825000    235.900000
# Glucides                               241.100000    875.400000
# Proteines                              184.175000    267.100000
# Breakfast_Calories                     692.250000   2310.000000
# Breakfast_Lipides                       23.325000    100.000000
# Breakfast_Glucides                      82.250000    314.000000
# Breakfast_Proteines                     74.825000    179.800000
# Dinner_Calories                        843.600000   3185.200000
# Dinner_Lipides                          25.100000    146.600000
# Dinner_Glucides                        113.900000    479.300000
# Dinner_Proteines                        54.900000    163.300000
# Lunch_Calories                         877.950000   5365.700000
# Lunch_Lipides                           24.800000    229.600000
# Lunch_Glucides                          84.600000    689.400000
# Lunch_Proteines                         90.550000    224.500000
# Snacks_Calories                        123.675000   2244.500000
# Snacks_Lipides                           3.100000    119.800000
# Snacks_Glucides                         22.125000    265.100000
# Snacks_Proteines                         4.075000     31.800000
# exo_secondes                          5734.301000  28800.000000
# exo_cals_bruts                         609.000000   2290.000000
# STRENGTH_TRAINING_exo_secondes        5296.720000   8762.855000
# STRENGTH_TRAINING_exo_cals_bruts       531.000000   1099.000000
# INDOOR_ROWING_exo_secondes            2837.212750  13800.740000
# INDOOR_ROWING_exo_cals_bruts           488.750000   2290.000000
# WALKING_exo_secondes                  7516.415500  28800.000000
# WALKING_exo_cals_bruts                 619.000000   1243.000000
# BOXING_exo_secondes                   1286.689000   1744.426000
# BOXING_exo_cals_bruts                  190.500000    240.000000
# RUNNING_exo_secondes                  1795.347500   2818.678000
# RUNNING_exo_cals_bruts                 247.250000    449.000000
# JOGGING_exo_secondes                  3635.250000   6108.884000
# JOGGING_exo_cals_bruts                 568.000000    842.000000
# CROSS-COUNTRY_SKIING_exo_secondes    12636.121500  13500.527000
# CROSS-COUNTRY_SKIING_exo_cals_bruts    822.250000    877.000000
# ROWING_exo_secondes                   1876.669000   1876.669000
# ROWING_exo_cals_bruts                  285.000000    285.000000
# TREADMILL_RUNNING_exo_secondes        2113.078000   2113.078000
# TREADMILL_RUNNING_exo_cals_bruts       258.000000    258.000000
# SWIMMING_exo_secondes                  600.000000    600.000000
# SWIMMING_exo_cals_bruts                 50.000000     50.000000
# DOWNHILL_SKIING_exo_secondes         13222.087750  15036.494000
# DOWNHILL_SKIING_exo_cals_bruts         361.500000    426.000000
